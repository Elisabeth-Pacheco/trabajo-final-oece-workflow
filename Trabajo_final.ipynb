# %%
# Trabajo Final — Workflow reproducible para convocatorias públicas del OECE

# Parte 1/3
# Diseño general del problema, objeto y propuesta

# Parte 2/3
# Desarrollo técnico del workflow o aplicación

# Parte 3/3
# Cierre: herramientas de IA generativa, programación, presentación y entrega
